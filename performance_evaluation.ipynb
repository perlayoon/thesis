# %%
from time import time
from joblib import dump, load

import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
# 데이터셋 불러오기
train = pd.read_csv('./data/train_refined.csv')
valid = pd.read_csv('./data/valid_refined.csv')
feature_rankings = pd.read_csv('./data/xai_result.csv')
# Out:
# 1.110095739364624

# %%
feature_rankings
# Out:
#                            feature  impurity  score  \
# 0                            Promo    0.1367      2
# 1                      DayOfWeek_1    0.0335      5
# 2       CompetitionOpenElapsedDays    0.1302      3
# 3                Promo2ElapsedDays    0.0413      4
# 4              CompetitionDistance    0.3928      1
# 5                         Month_12    0.0223      7
# 6                     Assortment_c    0.0112     14
# 7                     Assortment_a    0.0107     15
# 8   PromoInterval_Mar,Jun,Sept,Dec    0.0157     11
# 9                  PromoInterval_0    0.0206      8
# 10                     DayOfWeek_5    0.0059     20
# 11                   SchoolHoliday    0.0101     16
# 12                     DayOfWeek_6    0.0153     12
# 13                     StoreType_c    0.0168     10
# 14                       Year_2014    0.0046     22
# 15                       Year_2015    0.0048     21
# 16                     StoreType_b    0.0255      6
# 17                         Month_6    0.0034     29
# 18                     StoreType_a    0.0170      9
# 19                       Year_2013    0.0081     17
# 20                         Month_4    0.0044     25
# 21                         Month_3    0.0035     26
# 22                         Month_5    0.0045     24
# 23                         Month_8    0.0025     35
# 24   PromoInterval_Feb,May,Aug,Nov    0.0078     18
# 25                  StateHoliday_0    0.0011     37
# 26                     StoreType_d    0.0136     13
# 27                        Month_10    0.0026     34
# 28                     DayOfWeek_2    0.0064     19
# 29                     DayOfWeek_3    0.0034     30
# 30                         Month_1    0.0035     27
# 31                         Month_7    0.0034     28
# 32                  StateHoliday_b    0.0001     40
# 33                     DayOfWeek_4    0.0027     33
# 34                     DayOfWeek_7    0.0046     23
# 35                         Month_2    0.0028     32
# 36                         Month_9    0.0023     36
# 37                        Month_11    0.0032     31
# 38                  StateHoliday_a    0.0002     39
# 39                    Assortment_b    0.0007     38
# 40                  StateHoliday_c    0.0000     41
#
#                          feature.1      lime  score.1  total
# 0                            Promo  855.8936        1      3
# 1                      DayOfWeek_1  222.7965        2      7
# 2       CompetitionOpenElapsedDays   68.0728        7     10
# 3                Promo2ElapsedDays   74.8060        6     10
# 4              CompetitionDistance   54.9832       10     11
# 5                         Month_12  108.2533        4     11
# 6                     Assortment_c  117.1192        3     17
# 7                     Assortment_a  102.2983        5     20
# 8   PromoInterval_Mar,Jun,Sept,Dec   59.3330        9     20
# 9                  PromoInterval_0   20.9589       17     25
# 10                     DayOfWeek_5   66.2847        8     28
# 11                   SchoolHoliday   41.5591       14     30
# 12                     DayOfWeek_6   18.1944       20     32
# 13                     StoreType_c   12.0861       23     33
# 14                       Year_2014   50.2937       11     33
# 15                       Year_2015   40.6017       15     36
# 16                     StoreType_b    4.9299       33     39
# 17                         Month_6   46.6491       12     41
# 18                     StoreType_a    5.0342       32     41
# 19                       Year_2013   11.0348       25     42
# 20                         Month_4   20.8689       18     43
# 21                         Month_3   12.3560       22     48
# 22                         Month_5   11.6539       24     48
# 23                         Month_8   45.7517       13     48
# 24   PromoInterval_Feb,May,Aug,Nov    3.7747       34     52
# 25                  StateHoliday_0   24.0510       16     53
# 26                     StoreType_d    0.0183       41     54
# 27                        Month_10   17.0764       21     55
# 28                     DayOfWeek_2    1.3252       37     56
# 29                     DayOfWeek_3   10.8364       26     56
# 30                         Month_1    7.4224       30     57
# 31                         Month_7    7.9430       29     57
# 32                  StateHoliday_b   20.2587       19     59
# 33                     DayOfWeek_4    8.4170       28     61
# 34                     DayOfWeek_7    0.8957       40     63
# 35                         Month_2    6.3589       31     63
# 36                         Month_9    9.4833       27     63
# 37                        Month_11    2.9371       36     67
# 38                  StateHoliday_a    3.1678       35     74
# 39                    Assortment_b    1.2406       39     77
# 40                  StateHoliday_c    1.2891       38     79

# %%
# 순위로 정렬된 특징 집합
features = feature_rankings.feature

# %%
feature_set = list(features[:-1])

# %%
# 레이블 추가
feature_set.append("Sales")

# %%
feature_set
# Out:
# ['Promo',
#  'DayOfWeek_1',
#  'CompetitionOpenElapsedDays',
#  'Promo2ElapsedDays',
#  'CompetitionDistance',
#  'Month_12',
#  'Assortment_c',
#  'Assortment_a',
#  'PromoInterval_Mar,Jun,Sept,Dec',
#  'PromoInterval_0',
#  'DayOfWeek_5',
#  'SchoolHoliday',
#  'DayOfWeek_6',
#  'StoreType_c',
#  'Year_2014',
#  'Year_2015',
#  'StoreType_b',
#  'Month_6',
#  'StoreType_a',
#  'Year_2013',
#  'Month_4',
#  'Month_3',
#  'Month_5',
#  'Month_8',
#  'PromoInterval_Feb,May,Aug,Nov',
#  'StateHoliday_0',
#  'StoreType_d',
#  'Month_10',
#  'DayOfWeek_2',
#  'DayOfWeek_3',
#  'Month_1',
#  'Month_7',
#  'StateHoliday_b',
#  'DayOfWeek_4',
#  'DayOfWeek_7',
#  'Month_2',
#  'Month_9',
#  'Month_11',
#  'StateHoliday_a',
#  'Assortment_b',
#  'Sales']

# %%
# 학습데이터 준비 
x_train = train[feature_set[:-1]].to_numpy()
y_train = train[feature_set[-1]].to_numpy()
x_valid = valid[feature_set[:-1]].to_numpy()
y_valid = valid[feature_set[-1]].to_numpy()

# %% [markdown]
# ### RFE(Recursive Feature Elimination) 특징 선택
# + 전체 특징 집합에서 시작해서 특징 순위가 가장 낮은 것부터 순차적으로 제거 및 성능 측정

# %%
# RFR 모델 초기화
rfr = RandomForestRegressor(
    n_estimators=100, 
    random_state=15,
    bootstrap=True, 
    criterion='mse')

# %%
"""
    RFE(Recursive Feature Elimination) 특징 선택
"""

fs_size_lst = []
exec_time_lst = []
mae_lst = []

for i in range(len(features)):
    print('[%dth fs]' % (i))   
    # 특징 선택
    feature_set = list(features[:len(features)-i])
    feature_set.append("Sales")
    fs_size_lst.append(len(feature_set))
    print(len(feature_set))
    
    # 학습데이터 준비 
    x_train = train[feature_set[:-1]].to_numpy()
    y_train = train[feature_set[-1]].to_numpy()
    x_valid = valid[feature_set[:-1]].to_numpy()
    y_valid = valid[feature_set[-1]].to_numpy()
    
    # 모델 초기화
    rfr = RandomForestRegressor(
    n_estimators=100, 
    random_state=15,
    bootstrap=True, 
    criterion='mse')

    start = time()
    # 시간 측정 시작
    rfr.fit(x_train, y_train)
    # 시간 측정 종료
    end = time()
    print('Training time = %f' % (end-start)) 
    exec_time_lst.append(end-start)
    
    # MAE 측정
    y_hat = rfr.predict(x_valid)
    loss = mean_absolute_error(y_valid, y_hat)
    mae_lst.append(loss)
    print('Model loss = %f' % (loss))
    
#     # 모델 저장
#     print('dump the model...(./data/' + 'rfr_model_fs_size_' + str(len(feature_set)) + '.csv)')
#     dump(rfr, './data/' + 'rfr_model_fs_size_' + str(len(feature_set)) + '.csv')
    
    # 결과 저장
    df_result = pd.DataFrame()
    df_result['fs_size'] = fs_size_lst
    df_result['exec_time'] = exec_time_lst
    df_result['mae'] = mae_lst
    df_result.to_csv('./data/' + 'exp_result_fs_size_' + str(len(feature_set)) + '.csv' )
# Out:
# [0th fs]
# 42
# Training time = 302.114446
# Model loss = 712.448258
# dump the model...(./data/rfr_model_fs_size_42.csv)
# [1th fs]
# 41
# Training time = 339.183835
# Model loss = 712.528562
# dump the model...(./data/rfr_model_fs_size_41.csv)
# [2th fs]
# 40
# Training time = 331.770581
# Model loss = 712.471850
# dump the model...(./data/rfr_model_fs_size_40.csv)
# [3th fs]
# 39
# Training time = 315.939503
# Model loss = 712.362637
# dump the model...(./data/rfr_model_fs_size_39.csv)
# [4th fs]
# 38
# Training time = 304.002406
# Model loss = 715.980223
# dump the model...(./data/rfr_model_fs_size_38.csv)
# [5th fs]
# 37
# Training time = 295.678168
# Model loss = 717.656929
# dump the model...(./data/rfr_model_fs_size_37.csv)
# [6th fs]
# 36
# Training time = 290.710381
# Model loss = 719.700113
# dump the model...(./data/rfr_model_fs_size_36.csv)
# [7th fs]
# 35
# Training time = 281.493242
# Model loss = 721.401326
# dump the model...(./data/rfr_model_fs_size_35.csv)
# [8th fs]
# 34
# Training time = 278.033372
# Model loss = 725.225015
# dump the model...(./data/rfr_model_fs_size_34.csv)
# [9th fs]
# 33
# Training time = 273.282266
# Model loss = 725.252212
# dump the model...(./data/rfr_model_fs_size_33.csv)
# [10th fs]
# 32
# Training time = 266.276181
# Model loss = 729.307858
# dump the model...(./data/rfr_model_fs_size_32.csv)
# [11th fs]
# 31
# Training time = 254.831145
# Model loss = 731.924819
# dump the model...(./data/rfr_model_fs_size_31.csv)
# [12th fs]
# 30
# Training time = 244.556142
# Model loss = 731.893861
# dump the model...(./data/rfr_model_fs_size_30.csv)
# [13th fs]
# 29
# Training time = 231.719425
# Model loss = 749.636083
# dump the model...(./data/rfr_model_fs_size_29.csv)
# [14th fs]
# 28
# Training time = 228.275135
# Model loss = 750.096478
# dump the model...(./data/rfr_model_fs_size_28.csv)
# [15th fs]
# 27
# Training time = 219.712626
# Model loss = 750.491307
# dump the model...(./data/rfr_model_fs_size_27.csv)
# [16th fs]
# 26
# Training time = 214.236392
# Model loss = 752.655362
# dump the model...(./data/rfr_model_fs_size_26.csv)
# [17th fs]
# 25
# Training time = 212.582432
# Model loss = 753.181766
# dump the model...(./data/rfr_model_fs_size_25.csv)
# [18th fs]
# 24
# Training time = 205.914117
# Model loss = 753.679138
# dump the model...(./data/rfr_model_fs_size_24.csv)
# [19th fs]
# 23
# Training time = 197.330113
# Model loss = 758.290819
# dump the model...(./data/rfr_model_fs_size_23.csv)
# [20th fs]
# 22
# Training time = 187.805475
# Model loss = 759.842345
# dump the model...(./data/rfr_model_fs_size_22.csv)
# [21th fs]
# 21
# Training time = 179.510340
# Model loss = 761.824058
# dump the model...(./data/rfr_model_fs_size_21.csv)
# [22th fs]
# 20
# Training time = 170.888207
# Model loss = 762.098020
# dump the model...(./data/rfr_model_fs_size_20.csv)
# [23th fs]
# 19
# Training time = 169.442170
# Model loss = 768.383541
# dump the model...(./data/rfr_model_fs_size_19.csv)
# [24th fs]
# 18
# Training time = 158.611240
# Model loss = 772.175202
# dump the model...(./data/rfr_model_fs_size_18.csv)
# [25th fs]
# 17
# Training time = 149.577214
# Model loss = 770.966234
# dump the model...(./data/rfr_model_fs_size_17.csv)
# [26th fs]
# 16
# Training time = 142.923157
# Model loss = 780.751576
# dump the model...(./data/rfr_model_fs_size_16.csv)
# [27th fs]
# 15
# Training time = 129.545483
# Model loss = 786.992716
# dump the model...(./data/rfr_model_fs_size_15.csv)
# [28th fs]
# 14
# Training time = 128.235072
# Model loss = 803.532402
# dump the model...(./data/rfr_model_fs_size_14.csv)
# [29th fs]
# 13
# Training time = 124.751265
# Model loss = 905.706852
# dump the model...(./data/rfr_model_fs_size_13.csv)
# [30th fs]
# 12
# Training time = 115.087567
# Model loss = 931.583807
# dump the model...(./data/rfr_model_fs_size_12.csv)
# [31th fs]
# 11
# Training time = 105.311171
# Model loss = 937.493363
# dump the model...(./data/rfr_model_fs_size_11.csv)
# [32th fs]
# 10
# Training time = 107.396338
# Model loss = 949.522758
# dump the model...(./data/rfr_model_fs_size_10.csv)
# [33th fs]
# 9
# Training time = 102.560159
# Model loss = 959.792113
# dump the model...(./data/rfr_model_fs_size_9.csv)
# [34th fs]
# 8
# Training time = 96.971271
# Model loss = 960.028988
# dump the model...(./data/rfr_model_fs_size_8.csv)
# [35th fs]
# 7
# Training time = 102.420051
# Model loss = 1016.898880
# dump the model...(./data/rfr_model_fs_size_7.csv)
# [36th fs]
# 6
# Training time = 90.149166
# Model loss = 1041.475018
# dump the model...(./data/rfr_model_fs_size_6.csv)
# [37th fs]
# 5
# Training time = 63.106214
# Model loss = 1933.308689
# dump the model...(./data/rfr_model_fs_size_5.csv)
# [38th fs]
# 4
# Training time = 39.589017
# Model loss = 2059.335472
# dump the model...(./data/rfr_model_fs_size_4.csv)
# [39th fs]
# 3
# Training time = 2.779135
# Model loss = 2040.204815
# dump the model...(./data/rfr_model_fs_size_3.csv)
# [40th fs]
# 2
# Training time = 2.123982
# Model loss = 2080.445211
# dump the model...(./data/rfr_model_fs_size_2.csv)
